# %%
# ==  x == y ? True / Falso 
# !=  x =! y ? True / Falso 
# >   x > Y  ? Booleanos 
# <   x < y  ?
# >=  x >= 9 True
# <=  x <= 9 False   

temperatura = 28.5 
humedad = 65

# Mayor que 
hace_calor = temperatura > 25 
print(hace_calor)
# Out:
# True
